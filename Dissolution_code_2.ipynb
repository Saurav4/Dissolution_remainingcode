# %%
pwd
# Out:
# 'C:\\Users\\Saurav\\Dropbox\\Saurav\\dissolution announcements'

# %%
import os

# %%
myfile=open('gettingtext.txt',encoding="utf8") #getting text extracted from Dissolution_code_1 notebook

# %%
text=myfile.read()

# %%
text
# Out:
# '\nPage 1 of 1 © 2020 Factiva, Inc. All rights reserved.\n\nReliance Cap to buy AMP Sanmar for Rs 100 crore ; Reliance Capital will acquire AMP Sanmar Life\nInsurance Company for...\n\nFRENY PATEL & KAUSIK DATTA Mumbai\n223 words\n17 August 2005\nBusiness Standard\nBSTN\n1\nEnglish\n(c) 2005 Business Standard Ltd.\nReliance Capital will acquire AMP Sanmar Life Insurance Company for Rs 100 crore. Since the\nChennai-based life insurance entity has net free assets of Rs 60-65 crore, Reliance Cap will pay a premium\nof Rs 35-40 crore.\n\nNet free assets essentially denote the book value of an insurance company, calculated after deducting losses\nfrom its share capital. AMP Sanmar has a capital base of Rs 217.5 crore.\n\nThe non-banking finance arm of the Anil Dhirubhai Ambani Enterprise (ADAE) had initially decided to acquire\nAMP Sanmar through Reliance Life Insurance Company. But it was not possible as Reliance Life Insurance\nwas not a legal entity since it did not have a licence from the Insurance Regulatory and Development\nAuthority (IRDA).\n\nIRDA Chairman CS Rao told Business Standard since Reliance Life Insurance was not a legal entity, it could\nnot acquire AMP Sanmar. "It is important for Reliance to identify the acquirer as the next step will be the due\ndiligence exercise to be undertaken by the insurance regulator," he added. Declining to comment on the\nactual value of the deal, Graham Meyer, AMP Sanmar CEO, said it had not been a distress sale.\n\n \n\n\n\n\n\n\n\nPage 1 of 1 © 2020 Factiva, Inc. All rights reserved.\n\nBANKING/FINANCE\nAMP Sanmar Life is now Reliance Life\n\nOur Bureau\n173 words\n3 February 2006\nBusiness Line (The Hindu)\nBSNLNE\n06\nEnglish\n(c) 2006 The Hindu Business Line\nHyderabad , Feb. 2\n\nCONSEQUENT to the acquisition by Reliance Capital Ltdof the entire equity capital of AMP of Australia and\nSanmar Group in AMP Sanmar Life Insurance Co Ltd , the Insurance Regulatory and Development Authority\n(IRDA) has taken note of the change of company name, `AMP Sanmar Life Insurance Co Ltd\', to that of\nReliance Life Insurance Co Ltd (RLICL) and the fresh certificate of incorporation consequent to change of\nname issued by the Registrar of Companies, Tamil Nadu, dated January 17.\n\nThe insurance regulator said it had permitted RLICL to carry on life insurance business in India subject to the\ncondition that RLICL should honour its commitments to the policyholders of AMP Sanmar Life Insurance on\nthe same terms and conditions subject to which they were issued.\n\nFurther, the regulator said in a notice here that RLICL should take necessary steps to protect the interests of\nthe policyholders in accordance with the provisions of IRDA Act 1999 and Insurance Act 1938.\n\n\n\n\n\n\n\n\n\n\n\n\nPage 1 of 1 © 2020 Factiva, Inc. All rights reserved.\n\nMax Hypermarkets, Auchan end ties\n\nRaghavendra Kamath\n232 words\n12 August 2014\nBusiness Standard\nBSTN\nEnglish\n(c) 2014 Business Standard Ltd.\nMax Hypermarkets, part of Dubai\'s Landmark Group, and French
'  to that of Reliance Life Insurance Co Ltd (RLICL) and the fresh certificate of incorporation consequent to change of name issued by the Registrar of Companies  Tamil Nadu  dated January    The insurance regulator said it had permitted RLICL to carry on life insurance business in India subject to the condition that RLICL should honour its commitments to the policyholders of AMP Sanmar Life Insurance on the same terms and conditions subject to which they were issued  Further  the regulator said in a notice here that RLICL should take necessary steps to protect the interests of the policyholders in accordance with the provisions of IRDA Act   and Insurance Act    Page   of   ©   Factiva  Inc  All rights reserved  Max Hypermarkets  Auchan end ties Raghavendra Kamath   words   August   Business Standard BSTN English (c)   Business Standard Ltd  Max Hypermarkets  part of Dubai\'s Landmark Group  and French retailer Groupe Auchan have ended their two year old licence agreement in India  The failure to convert that agreement into a joint venture is the reason for ending the relationship  Max Hypermarkets said today  "Max Hypermarkets and Groupe Auchan continued deep into   to look into the possibilities of creating a joint venture to facilitate Groupe Auchan investment in India  which could comply with Indian FDI regulations  Despite their best efforts  the parties could not facilitate this proposition " Max said in a statement  "Therefore  by common agreement  the   Max Hypermarkets will no longer operate under the Auchan banner by January   at the latest " it said This is the second break-up for Max as it ended its ties with Dutch retailer Spar International in May    After tying up with Auchan  Max rebranded its existing \'SPAR\' stores in Bangalore and Mangalore to \'Auchan\'  In September    the UPA government allowed foreign direct investment in multi brand retail subject to approval of respective states  Barring UK-based Tesco  none of the foreign chains has applied for FDI in multi brand retail so far  Max Hypermar ...

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
doc=nlp(z)

# %%
text_no_namedentities = []

#removing named entities like name of companies,People's names,Organization name ,etc
ents = [e.text for e in doc.ents]
for item in doc:
    if item.text in ents:
        pass
    else:
        text_no_namedentities.append(item.text)
pre=(" ".join(text_no_namedentities))


pre
# Out:
# 'Page    of    ©    Factiva     All rights reserved   Cap to buy AMP Sanmar for    crore ; Capital will acquire AMP Sanmar Life Insurance for   FRENY PATEL & KAUSIK DATTA    words       Business Standard BSTN    ( c )    Business Standard Ltd   Capital will acquire AMP Sanmar Life Insurance for    crore   Since the - based life insurance entity has net free assets of   -   crore   Cap will pay a premium of   -   crore   Net free assets essentially denote the book value of an insurance company   calculated after deducting losses from its share capital   AMP Sanmar has a capital base of      crore   The non - banking finance arm of the Anil Dhirubhai Ambani Enterprise ( ) had initially decided to acquire AMP Sanmar through Life Insurance   But it was not possible as Life Insurance was not a legal entity since it did not have a licence from the Insurance Regulatory and Development Authority ( IRDA )   IRDA Chairman CS Rao told Business Standard since Life Insurance was not a legal entity   it could not acquire AMP Sanmar   " It is important for to identify the acquirer as the next step will be the due diligence exercise to be undertaken by the insurance regulator " he added   Declining to comment on the actual value of the deal   Graham Meyer   AMP Sanmar CEO   said it had not been a distress sale     Page    of    ©    Factiva     All rights reserved   BANKING FINANCE AMP Sanmar Life is now Life Our Bureau    words       Business Line ( The ) BSNLNE    ( c )    The Business Line        CONSEQUENT to the acquisition by Capital Ltdof the entire equity capital of AMP of and Sanmar Group in AMP Sanmar Life Insurance Co Ltd    the Insurance Regulatory and Development Authority ( IRDA ) has taken note of the change of company name   ` AMP Sanmar Life Insurance Co Ltd \'   to that of Life Insurance Co Ltd ( ) and the fresh certificate of incorporation consequent to change of name issued by the Registrar of Companies   Tamil Nadu   dated     The insurance regulator said it had permitted to carry on life insurance business in subject to the condition that should honour its commitments to the policyholders of AMP Sanmar Life Insurance on the same terms and conditions subject to which they were issued   Further   the regulator said in a notice here that should take necessary steps to protect the interests of the policyholders in accordance with the provisions of IRDA Act    and Insurance Act     Page    of    ©    Factiva     All rights reserved   Hypermarkets   end ties Raghavendra Kamath    words       Business Standard BSTN ( c )    Business Standard Ltd   Hypermarkets   part of \'s Landmark Group   and retailer Groupe have ended their old licence agreement in   The failure to convert that agreement into a joint venture is the reason for ending the relationship   Hypermarkets said   " Hypermarkets and Groupe continued deep into    to look into the possibilities of creating a joint venture to facilitate Groupe investment in   which could comply with FDI regulations   Despite their best efforts   the parties could not facilitate this proposition " said in a statement   " Therefore   by common agreement   the    Hypermarkets will no longer operate under the banner by    at the latest " it said This is the break - up for as it ended its ties with retailer Spar International in     After tying up with   rebranded its existing \' \' stores in and Mangalore to \' \'   In     the UPA government allowed foreign direct investment in multi brand retail subject to approval of respective states   Barring - based   none of the foreign chains has applied for FDI in multi brand retail so far   Hypermarket is committed to growth and development of the hypermarket and supermarket business in and will continue its investments under a new brand name   the based company said   Page    of    ©    Factiva     All rights reserved   Retail Stores spent     mn to end its deal with Enterprises   resulting in a net loss of     mn Rasul Bailay & Sagar Malviya    wo ...

# %%
import pandas as pd
# removing some words not recognized as entities bu 

removewords = ['factiva','srivats','singh','AMP Sanmar','titagarh','bj','venugopal', 'rajagopal','aroq','giorgio','wsj','ntt','ruchi','giorgio','biswajit','mohan','frigo',
              'elizabeth', 'shankar','bn','wal','prizm','lombard','gulati','sca','vide','usa','nikhil','tamil','ttsl','dplm','khaimah',
             'pramerica','hai','apollo','bombay','foray','delhi','mccumiskey','www','nayantara', 'mpvi', 'irda','fipb','nippon','mr','hersun','rajagopal',
              'tata','croda','kim','eagleeye','htsyndication','sl','sjk','aman','nihon','beteiligungsgesellschaft','airtel','sagar', 'eagle','av','ve',
              'di','ashok','charmi','htaccf','said','dr','vijaya','chemiphar','ambani','ft','sermo','efs','mittal','piyush','rico','murugappa',
              'sanmar','htsyndication','jcn','ramanathan','ht','jasper','mckinsey','york','jasper','divya','druva','cholamandalam','dpin','sankyo','shravan',
              'johns','bhandari','ve','vcc','deloite','rancher','lacto','jones','bali','coleman','changapally','kit','fy','anil','arm','cap','non','bstn','did','page']
querywords = pre.split()

resultwords  = [word for word in querywords if word.lower() not in removewords]
result = ' '.join(resultwords)


#splitting text file into 3 parts so that max_df and min_df work and very high and low frequency words are removed
data = {'col':[result[:500]]}      
  
# Create DataFrame 
df = pd.DataFrame(data) 
  
# Print the output.
df['col'][1]=result[500:1000]
df['col'][2]=result[1000:]









#print(result)

#result=[result]
#pre=[pre]

 
#nlp.Defaults.stop_words.add('factiva') 
#nlp.vocab['factiva'].is_stop
#data = {'col':[pre]} 
  
# Create DataFrame 
#df = pd.DataFrame(data) 
  
# Print the output.
#df

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_df=0.9,min_df=2,stop_words='english')

# %%
from sklearn.decomposition import NMF

# %%
dtm=tfidf.fit_transform(df['col'])
model=NMF(n_components=12,random_state=42)

# %%
model.fit(dtm)
model.components_.shape
# Out:
# (12, 36)

# %%
fir=model.components_[0]
fir10=fir.argsort()[-15:]
for i in fir10:
    print(tfidf.get_feature_names()[i])  #checking first topic
# Out:
# authority
# told
# enterprise
# licence
# important
# initially
# step
# chairman
# development
# regulatory
# possible
# exercise
# acquirer
# decided
# legal

# %%
for index, topic in enumerate(model.components_):
    print(f"The top 15 words for topic {index}")
    print([tfidf.get_feature_names()[i] for i in topic.argsort()[-15:]])
# Out:
# The top 15 words for topic 0
# ['authority', 'told', 'enterprise', 'licence', 'important', 'initially', 'step', 'chairman', 'development', 'regulatory', 'possible', 'exercise', 'acquirer', 'decided', 'legal']
# The top 15 words for topic 1
# ['share', 'banking', 'losses', 'assets', 'premium', 'value', 'net', 'buy', 'based', 'reserved', 'words', 'company', 'rights', 'capital', 'crore']
# The top 15 words for topic 2
# ['based', 'value', 'licence', 'important', 'premium', 'told', 'buy', 'regulatory', 'chairman', 'development', 'decided', 'words', 'reserved', 'rights', 'company']
# The top 15 words for topic 3
# ['step', 'decided', 'legal', 'exercise', 'initially', 'enterprise', 'licence', 'important', 'identify', 'told', 'chairman', 'regulatory', 'possible', 'development', 'authority']
# The top 15 words for topic 4
# ['words', 'value', 'losses', 'premium', 'base', 'pay', 'banking', 'share', 'essentially', 'book', 'net', 'assets', 'crore', 'free', 'capital']
# The top 15 words for topic 5
# ['capital', 'development', 'base', 'essentially', 'net', 'crore', 'company', 'rights', 'share', 'buy', 'words', 'value', 'losses', 'based', 'reserved']
# The top 15 words for topic 6
# ['capital', 'chairman', 'regulatory', 'important', 'told', 'licence', 'enterprise', 'initially', 'exercise', 'acquirer', 'possible', 'step', 'legal', 'authority', 'identify']
# The top 15 words for topic 7
# ['crore', 'important', 'regulatory', 'share', 'chairman', 'licence', 'decided', 'told', 'buy', 'based', 'words', 'reserved', 'development', 'rights', 'company']
# The top 15 words for topic 8
# ['premium', 'value', 'buy', 'book', 'banking', 'free', 'share', 'essentially', 'pay', 'losses', 'base', 'assets', 'net', 'crore', 'capital']
# The top 15 words for topic 9
# ['development', 'regulatory', 'possible', 'chairman', 'licence', 'exercise', 'enterprise', 'told', 'identify', 'authority', 'important', 'initially', 'legal', 'step', 'acquirer']
# The top 15 words for topic 10
# ['possible', 'acquirer', 'legal', 'chairman', 'important', 'initially', 'exercise', 'regulatory', 'development', 'step', 'decided', 'told', 'identify', 'licence', 'enterprise']
# The top 15 words for topic 11
# ['buy', 'losses', 'crore', 'capital', 'based', 'share', 'premium', 'essentially', 'value', 'banking', 'free', 'assets', 'base', 'pay', 'net']
